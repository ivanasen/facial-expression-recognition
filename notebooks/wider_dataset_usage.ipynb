# %%
import matplotlib.pyplot as plt
from matplotlib import patches
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

sys.path.append("../")
from models.yolo_face_detector import YoloFaceDetector

from models.yolo.dataset import WiderDataset
from models.yolo import utils

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
anchors = utils.get_anchors("../model_config/wider_anchors.txt")

# %%
ds = WiderDataset(dataset_dir="../data", dataset_size="5", dataset_split="validation", classes_count=1, anchors=anchors, batch_size=1)

# %%
fig, ax = plt.subplots(1)

for image, _ in ds:
    # image *= 255
    plt.imshow(image.reshape(608, 608, 3))

plt.tight_layout()
plt.draw()
plt.show()
